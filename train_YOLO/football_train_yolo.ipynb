# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %% [markdown]
# ### Dowload data

# %%
rf = Roboflow(api_key="U8JLI9602YrqnouAN5ZN")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'e:\\DuAnCaNhan\\FootBallAnalysisSystem\\train_YOLO\\football-players-detection-1'

# %% [markdown]
# ### Tranning

# %%
model = YOLO("yolo26m.pt")

# %%
results = model.train(
    data="football-players-detection-1\data.yaml", # Đường dẫn tới file cấu hình
    epochs=100,    
    patience=10,              
    imgsz=640,
    batch=4,                   
    device=0,                  
    plots=True,                 # Tự động vẽ biểu đồ đánh giá (Loss, mAP)
    save=True                   # Lưu lại file trọng số (weights)
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.84 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.78  Python-3.11.9 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=football-players-detection-1\data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2804784  ultralytics.nn.modules.head.Detect           [4, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,779,056 parameters, 21,779,056 gradients, 74.7 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.1 ms, read: 427.454.7 MB/s, size: 226.0 KB)
# train: Scanning E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\football-players-detection-1\train\labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612  0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.20.2 ms, read: 182.3155.1 MB/s, size: 209.9 KB)
# val: Scanning E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\football-players-detection-1\valid\labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.71G      1.327      1.609   0.001152        191        640: 100% ━━━━━━━━━━━━ 153/153 3.3it/s 46.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.8it/s 0.9s0.2s
#                    all         38        905      0.699      0.628       0.62      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.93G      1.256     0.6758   0.001072        176        640: 100% ━━━━━━━━━━━━ 153/153 3.5it/s 44.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.838      0.709       0.76       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       2.9G      1.323       0.61   0.001087        179        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.892      0.733      0.789       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.95G      1.291     0.5565   0.001068        129        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.1it/s 0.8s0.2s
#                    all         38        905      0.891      0.751      0.829      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.94G      1.305     0.5819   0.001078        228        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.1it/s 0.8s0.2s
#                    all         38        905      0.823      0.695      0.771      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G      1.265     0.5137   0.001071        131        640: 100% ━━━━━━━━━━━━ 153/153 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.4it/s 0.8s0.2s
#                    all         38        905      0.866      0.777      0.837      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       2.9G      1.363     0.5181   0.001158        273        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.4it/s 0.8s0.2s
#                    all         38        905       0.89      0.779       0.84      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.93G      1.232     0.4629   0.001032        139        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.5it/s 0.8s0.2s
#                    all         38        905      0.864      0.789      0.811      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.94G       1.21     0.4429   0.000987        187        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.1it/s 0.8s0.2s
#                    all         38        905       0.84      0.798      0.829      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.95G      1.202     0.4305  0.0009933        252        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.873      0.804      0.835      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.92G      1.192     0.4178  0.0009518        134        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.1it/s 0.8s0.2s
#                    all         38        905      0.905      0.769      0.827      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.93G      1.206     0.4258  0.0009887        151        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.883      0.769       0.83      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.93G      1.183     0.4155  0.0009806        199        640: 100% ━━━━━━━━━━━━ 153/153 3.3it/s 46.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.6it/s 0.9s0.2s
#                    all         38        905      0.946      0.742      0.836      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.95G      1.108     0.3876   0.000904        151        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.5it/s 0.8s0.2s
#                    all         38        905       0.88      0.769       0.84      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100       2.9G      1.132     0.3912  0.0009255        160        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.881      0.803      0.849      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.84G      1.156     0.3921  0.0009721        162        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 44.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.955      0.772      0.851      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.91G      1.174     0.4077  0.0009429        159        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.1it/s 0.8s0.2s
#                    all         38        905      0.965      0.803      0.854      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.89G      1.168     0.3952  0.0009528        109        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 44.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.5it/s 0.8s0.2s
#                    all         38        905      0.929      0.774      0.832      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.94G      1.161     0.3878  0.0009142        168        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.948      0.769      0.848      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.94G      1.115      0.374  0.0008923        155        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.5it/s 0.8s0.2s
#                    all         38        905      0.928      0.815      0.861      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.96G      1.095     0.3639  0.0009046        147        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.921      0.831      0.873      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.93G      1.122     0.3682  0.0008832        146        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.888      0.816      0.833       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.93G      1.058     0.3401  0.0008571        116        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.0it/s 0.8s0.2s
#                    all         38        905      0.893      0.838       0.85       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.88G      1.128     0.3689  0.0008977        160        640: 100% ━━━━━━━━━━━━ 153/153 3.3it/s 46.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.911      0.823      0.856      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.94G       1.09     0.3563  0.0009036        208        640: 100% ━━━━━━━━━━━━ 153/153 3.7it/s 41.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.6it/s 0.7s0.2s
#                    all         38        905      0.906      0.832      0.855      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.93G      1.107     0.3608  0.0008803        149        640: 100% ━━━━━━━━━━━━ 153/153 3.7it/s 40.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.0it/s 0.7s0.2s
#                    all         38        905       0.96      0.828      0.866      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.93G      1.103     0.3556   0.000873        131        640: 100% ━━━━━━━━━━━━ 153/153 3.5it/s 44.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.923      0.809      0.856      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.92G      1.146     0.3731  0.0008942         90        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.916      0.836      0.861       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.88G      1.104     0.3645  0.0008792         90        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.3it/s 0.8s0.2s
#                    all         38        905      0.916      0.842      0.852      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.89G      1.063     0.3421  0.0008351        121        640: 100% ━━━━━━━━━━━━ 153/153 3.4it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.2it/s 0.8s0.2s
#                    all         38        905      0.913      0.813       0.85      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.87G      1.074     0.3448  0.0008425        144        640: 100% ━━━━━━━━━━━━ 153/153 3.6it/s 42.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.4it/s 0.7s0.2s
#                    all         38        905      0.961      0.846      0.868      0.589
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.88G       1.04     0.3275  0.0008125        107        640: 100% ━━━━━━━━━━━━ 153/153 3.8it/s 40.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.1it/s 0.7s0.2s
#                    all         38        905      0.956      0.846      0.872      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.88G      1.042     0.3254   0.000821         82        640: 100% ━━━━━━━━━━━━ 153/153 3.8it/s 40.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.1it/s 0.7s0.2s
#                    all         38        905      0.894       0.81      0.843      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.92G      1.056     0.3311  0.0008404        169        640: 100% ━━━━━━━━━━━━ 153/153 3.8it/s 40.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.4it/s 0.7s0.2s
#                    all         38        905      0.947      0.835      0.868      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.88G      1.068      0.332  0.0008117        119        640: 100% ━━━━━━━━━━━━ 153/153 3.8it/s 40.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.6it/s 0.7s0.2s
#                    all         38        905      0.957      0.808      0.852      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.93G      1.068      0.333  0.0008628         94        640: 100% ━━━━━━━━━━━━ 153/153 3.8it/s 40.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.2it/s 0.7s0.2s
#                    all         38        905      0.899      0.817      0.837      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.93G      1.014     0.3116  0.0008244        175        640: 100% ━━━━━━━━━━━━ 153/153 3.7it/s 41.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 7.3it/s 0.7s0.2s
#                    all         38        905      0.959      0.789      0.849      0.593
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 27, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 37 epochs completed in 0.478 hours.
# Optimizer stripped from E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train\weights\last.pt, 44.0MB
# Optimizer stripped from E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train\weights\best.pt, 44.0MB
#
# Validating E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train\weights\best.pt...
# Ultralytics 8.4.78  Python-3.11.9 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# YOLO26m summary (fused): 132 layers, 20,352,536 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.2it/s 1.0s0.3s
#                    all         38        905      0.923      0.809      0.856      0.605
#                   ball         35         35      0.853      0.429      0.484      0.247
#             goalkeeper         27         27      0.909      0.926      0.981      0.748
#                 player         38        754      0.973       0.97      0.984      0.772
#                referee         38         89      0.957       0.91      0.973      0.653
# Speed: 0.2ms preprocess, 18.7ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to E:\DuAnCaNhan\FootBallAnalysisSystem\train_YOLO\runs\detect\train
